# %% [markdown]
# ## Data Visualization with Matplotlib

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Learning Goals

# %% [markdown]
# - Recognize the components of a **matplotlib** plot
# - Create the following visualizations
#     - line chart
#     - scatter plot
#     - histogram
# - Plot data using  `plt.plot()`
# - Customize the components of the plot
# - Create subplots to create multiple plots simultaneously
# - Select an appropriate visualization type for data
#
# [Course page](https://ds.codeup.com/python/intro-to-matplotlib/)
#
# [Matplotlib Documentation](https://matplotlib.org/stable/)

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ### Import statements

# %%
from matplotlib import pyplot as plt
import pandas as pd
from pydataset import data

## Data generation
import numpy as np
import random

## Mathematical functions
import math

## Random seed value to reproduce results
np.random.seed(123)


# Set retina for higher resolution display
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ## Role of Visualizations

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ### Chart Types

# %% [markdown]
# ### Line Charts
#
# - Line charts connect values with a line
# - Shows changes in values over time
# - Time values should not have gaps
#
#
# ### Scatter plots
#
# - Scatter plots display values as separate points
# - Used for two continuous numerical variables
# - Markers represent the paired values $(x, y)$
#
#
#
# ### Histograms
#
# [Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html)
#
# - Shows distribution of data
# - Values are sorted into **bins**
# - $x$-axis is divided into intervals based on number of bins
# - $y$-axis plots the count (frequency) of values within the bin

# %% [markdown]
# ---
# <div class="alert alert-block alert-success">
#
# ### Basic exampleshttps://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xticks.html

# %% [markdown]
# ---
# ### Default line chart example using `plt.plot()`

# %%
# Create datasets
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [2, 4, 6, 8, 10, 12, 14, 16]
z = [3, 6, 9, 12,  15, 18, 21, 24]

# %%
# Plot with  plt.plot
plt.plot(x, y)
plt.plot(x,z);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 # Plot with  plt.plot
# ----> 2 plt.plot(x, y)+1
#       3 plt.plot(x,z)
#
# TypeError: can only concatenate list (not "int") to list

# %% [markdown]
# ---
# ### Default scatter plot example using `plt.scatter()`

# %%
## Create multiple data sets using np.random
x_1 = np.random.rand(20)
y_1 = np.random.rand(20)


x_2 = np.random.rand(20)
y_2 = np.random.rand(20)

# %%
# Plot with  plt.scatter
plt.scatter(x_1, y_1, c = 'red')
plt.scatter(x_2, y_2)
plt.show();

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Important notes
#
#
# - Jupyter notebooks will automatically display the figure after running the cell.
#
# - Otherwise, use the code below to display the figure.
#
# `plt.show()`
#
# - End the block of code with `;` to suppress additional output

# %% [markdown]
# ### Customization
#
# `matplotlib` has the capability to set and customize the following:
#
# - Line color and width
# - Line style
# - Plot markers
# - Color
# - Grid lines
# - Tick marks
# - Axis
# - Labels and titles
# - Font size

# %% [markdown]
# ---
# <div class="alert alert-block alert-success">
#
# ### Color options

# %% [markdown]
# [Documentation](https://matplotlib.org/stable/gallery/color/named_colors.html)
#
# Set a color using `color =` or `c = `
#
# - [Named colors](https://matplotlib.org/stable/gallery/color/named_colors.html)
# - RGB value [e.g. (0.1, 0.2, 0.5)]
# - Hex values e.g. #ffffff
# - Color palettes
#
# Set a **transparency** level as a float from 0 to 1 with `alpha = `

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example
#
# Apply the color options to the code below

# %%
# Plot with  plt.plot
plt.plot(x, y, color = 'red')
plt.plot(x, z, c = 'palevioletred', alpha = 0.25);

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ### Marker options

# %% [markdown]
# [Documentation](https://matplotlib.org/stable/api/markers_api.html)
#
# Set the **marker type** with the notation below
#
# | Notation | Description |
# |----|-----|
# | `.` | point |
# | `r+` | red plus |
# | `x` | x |
# | `X` | filled x  |
# | `,` | pixel |
# | `^` | triangle |
# | `*` | star |
#
# Set the **marker size** as float using the parameter ```markersize =``` or ```ms =```

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example
#
# Apply the marker options to the code below

# %%
# Plot with  plt.plot
# Set markers
plt.plot(x, y, 'x', ms = 6, c = 'red')
plt.plot(x, z, '*', ms = 8);

# %% [markdown]
# ---
# <div class="alert alert-block alert-success">
#
# ### Line options

# %% [markdown]
# [Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)
#
#
# Set the **line style** using the parameter ```linestyle=``` or ```ls=```
#
#
# | Notation | Description |
# |----|-----|
# | '-' | solid  |
# | '--' | dashed  |
# |'-.' | dash-dot |
# |':'| dotted |
#
#
# Set the **line width** as a float using the parameter ```linewidth =``` or ```lw =```

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example
# Apply the line options to the code below

# %%
# Plot with  plt.plot
plt.plot(x, y, linestyle = '-.')
plt.plot(x, z, ls = ':', lw = 5);

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
#
# ### Format strings

# %% [markdown]
# Combine marker, line, and color options into a format string.
#
#
# `'[marker][line][color]'`
#
# Color is abbreviated: `r`, `y`, `b` etc.
#
# **Example**
#
# ```python
# plt.plot(x, z, 'xg-');
# ```
#
# If no option is given, the default will be used

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example
#
# - Create and apply a format string to the code below

# %%
# Plot with  plt.plot
plt.plot(x, y, linestyle = '-')
plt.plot(x, z, 'xg--');

# %% [markdown]
# ---
# <div class="alert alert-block alert-success">
#
# ### Gridlines

# %% [markdown]
# [Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.grid.html)
#
# **Gridlines** are horizontal and vertical lines in the background of the plot
#
# Remove
# ```python
# plt.grid(None)
# ```
#
# Set parameters
#
# ```python
# plt.grid(color= , linestyle =  , linewidth = );
# ```

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example
#
# - Apply values for the gridline parameters below

# %%
## Plot with  plt.plot
plt.plot(x, y, 'r+');


#plt.grid(None)
plt.grid(color='gray', linestyle='--', linewidth=0.05);

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ### $x$-axis and $y$-axis

# %% [markdown]
# [Documentation x limits](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlim.html)
#
#
# [Documentation y limits](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylim.html)
#
#
# The $x$ and $y$ **axis** are horizontal and vertical lines.
#
# `Matplotlib` will automatically assign limits based on the data
#
#
# - Set the $x$ axis limit manually as floats $a$ and $b$
#
# ```python
# plt.xlim(a, b)
# ```
#
# - Set the $y$ axis limit manually as floats $a$ and $b$
#
# ```python
# plt.ylim(a, b)
# ```

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example
#
# - Set $x$ and $y$ limits for the plot below

# %%
# Plot two lines with  plt.plot

plt.xlim(10, 60)
plt.ylim(0, 50)
plt.plot(x, z)
plt.plot(x, y);

# %% [markdown]
# ---
# <div class="alert alert-block alert-success">
#
# ### Titles and labels

# %% [markdown]
# Axis labels and titles describe the contents of the plot.
#
# Set them with a string and/or **LaTeX** notation
#
# #### Plot title
#
# ```python
# plt.title('A descriptive title')
# ```
#
# #### Axis label with text
#
# ```python
# plt.xlabel('x')
# ```
#
# #### Axis label with LaTeX
#
# ```python
# plt.ylabel('$x^2$')
# ```

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example 1
#
#
# The data plotted below measures the bacterial growth for E. coli. This bacteria can double in number every 20 minutes.
#
# - Create titles and axis labels for the plot below.
# - Customize the chart however you see fit.

# %%
# Create data

# Set time values in increments of 20 
time = range(1, 600, 20)

## Set initial number of bacteria equal to 1
initial = 1


bacteria = [ initial * np.float_power(2, (0.05*n)) for n in time ]

# %%
## Plot the values
plt.plot(time, bacteria);
plt.title('A descriptive title')
plt.xlabel('this is the x label')
plt.ylabel('this is the y label')
# Out:
# Text(0, 0.5, 'this is the y label')

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example 2
#
# - Extend the time range above to 600 minutes.
#
# - What happens to the $y$-axis?

# %% [markdown]
# ---
# <div class="alert alert-block alert-success">
#
# ### Scientific Notation

# %% [markdown]
# Used to display very large or very small values.
#
# - Bases are raised to a power of 10.
# - Bases must be between -10 and 10
# - Move the decimal point to the left or right
#
# #### Examples
#
# $3.0E6 = 3 \times 10^6 = 3,000,000$
#
# $2.5E-6 = 2.5
# \times 10^{-6} = .0000025$

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ### LaTeX

# %% [markdown]
# $\LaTeX$ is a typesetting language widely used for mathematical symbols and notation.
#
# Enclose LaTeX code inside `$`
#
# See the cells below for examples:

# %% [markdown]
# | LaTeX  | Result |
# |---|---|
# | `$x$`  | $x$ |
# | `$H_0$`  | $H_0$ |
# | `$x_{t+1}$`  | $x_{t+1}$ |
# | `$x^2$`  | $x^2$ |
# | `$x^{a+b}$`  | $x^{a + b}$ |
# | `$f(x)$` | $f(x)$ |
# | `\Omega` | $\Omega$ |
# | `\gamma` | $\gamma$ |
# | `\frac{a}{b}` | $\frac{a}{b}$ |
# | `\dfrac{a}{b}` | $\dfrac{a}{b}$ |

# %% [markdown]
# ---
# <div class="alert alert-block alert-success">
#
# ### Tick Marks

# %% [markdown]
# [Documentation x-ticks](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xticks.html)
#
# [Documentation y-ticks](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xticks.html)
#
#
# Tick marks divide an **axis** and provide a reference for the plotted values
#
# ***Major*** tick marks can be further subdivided with ***minor*** tick marks.
#
# Labels can be applied to the tick marks.
#
# ```python
# plt.yticks()
# ```
# ```python
# plt.xticks()
# ```
#
# **Rotation** positions the tick mark label at a specified angle
#
#
# ```rotation = degrees ```
# #### Example
#
# ```python
# plt.yticks([1, 2, 3, 4], ['one', 'two', 'three', 'four'], rotation=45)
# ```

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example
#
# Create a line chart with ticks that represent days of the week

# %%
weekdays = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'] * 2

x = range(14)
y = [random.randint(1, 10) for _ in x]

# plot values
plt.plot(x, y)


plt.xticks(x, weekdays, rotation=60)
plt.show()

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
#
# ### Text and Annotations

# %% [markdown]
# #### Example with `plt.text()`
# Text information can be placed within a chart. LaTeX typesetting can also be used.
#
# Specify the location with a coordinate $(x, y)$
#
# Apply fontsize and color as needed.
#
# ```python
# plt.text(x, y, 'text', fontsize = , color = )
# ```

# %% [markdown]
# #### Example with `plt.annotate()`
#
# [Documentation](https://matplotlib.org/stable/tutorials/text/annotations.html#sphx-glr-tutorials-text-annotations-py)
#
# [Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.annotate.html)
#
# Specify the location with `xy = (x, y)`
#
# Apply fontsize and color as needed.
#
# ```python
# plt.annotate('Intersection', xy=(0, 0), xytext=(-3, 5),
#              arrowprops={'facecolor': 'blue'})
# ```

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example
#
# - Add text to describe the sine graph
# - Add an annotation to denote where two graphs intersect

# %%
x = list(range(-4, 4))
x.append(3.14159)
y = [math.sin(n) for n in x]

plt.scatter(x, y)
plt.plot(x, y, ls=':')

plt.text(0.25, 0, '(0, 0)', fontsize=10, color='blue')
plt.text(1.2, 0.1, '($\pi$, sin($\pi$))', fontsize=14, color='firebrick')

plt.show()

# %%
x = range(-3, 10)
y = [n * 2 for n in x]
z = [n / 2 for n in x]

plt.plot(x, y, c='orange')
plt.plot(x, z, c='green')

plt.annotate('Intersection', xy=(0, 0), xytext=(-3, 5),
             arrowprops={'facecolor': 'blue'})

plt.show()

# %% [markdown]
# ---
# <div class="alert alert-block alert-success">
#
# ### Figure size

# %% [markdown]
# Set the figure size with two values (width, height)
# ```python
# plt.figure(figsize=(14, 6))
# ```

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example
#
# Create or recreate any example graph. Set the figure size to an appropriate value.

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ### Legend

# %% [markdown]
# [Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html)
#
# Create a **legend** to represent the various components of the chart using a label and color.
#
# - Use string as description e.g. `'upper right'`
# - Use location code from 0-9
#
# ```python
# plt.legend(loc =)
# ```

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example
#
# Create two plots to represent the sine and cosine function. Add a legend to describe the two plots.

# %%
x = range(-4, 5)
sin_x = [math.sin(n) for n in x]
cos_x = [math.cos(n) for n in x]

plt.figure(figsize=(14, 6)) # (width, height)

plt.scatter(x, sin_x, c='blue')
plt.scatter(x, cos_x, c='orange')
plt.plot(x, sin_x, c='blue', label='$\sin(x)$')
plt.plot(x, cos_x, c='orange', label='$\cos(x)$')

plt.legend(loc=10)
plt.title('Approximate sin and cosine curves')
plt.xlabel('$x$')


plt.show()

# %% [markdown]
# ---
# <div class="alert alert-block alert-success">
#
# ### Subplots

# %% [markdown]
# Subplots create multiple charts within one area.
#
# - Determine how many subplots will be needed
# - Determine the number of **rows** and number of **columns**
# - Set the active subplot with an integer
#
# #### Method 1
#
# ```python
# plt.subplot(n_rows, n_cols, 1)
# ```
#
# #### Method 2
#
# ```python
# plt.subplot(221)
# ```
#
# Note: Method 2 is used for at most 9 subplots
#
#
# #### Figure Title
#
# Set an overall title for the figure:
#
# ```python
# plt.suptitle('Figure title')
# ```

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example
#
# Create two plots placed vertically.

# %%
# Example data

x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]
z = [1, 2, 3, 4, 5]

# %%
#first subplot
plt.subplot(121)
plt.plot(x, y)
plt.title('x ~ y')

#second subplot
plt.subplot(122)
plt.plot(x, z)
plt.title('x ~ z')

plt.suptitle('Demo of Subplots')
plt.show()

# %% [markdown]
# ## Histograms

# %% [markdown]
# - Shows distribution of data
# - Values are sorted into **bins**
# - $x$-axis is divided into intervals based on number of bins
# - $y$-axis plots the count (frequency) of values within the bin

# %% [markdown]
# ---
# ### Default histogram example using `plt.hist()`

# %%
x = [1, 1, 2, 3, 3, 3, 4, 4, 5]

plt.hist(x)
plt.show()

# %% [markdown]
# ## Bins and alignment
#
# - Bin values are the intervals in which values are placed.
# - The width of the bin is the difference between the start and end of a bin
# - Bin alignment set how the bars are aligned relative to the bin values

# %%
## Data
x = [1, 1, 2, 3, 3, 3, 4, 4, 5]

# bin width is 1
# number of bins is 6

plt.hist(x, bins=[0, 1, 2, 3, 4, 5, 6])
plt.grid(False)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example - Bin alignment

# %% [markdown]
# - Create three histograms as subplots.
# - Set the alignment value to 'default', 'left', and 'right'

# %%
x = [1, 1, 2, 3, 3, 3, 4, 4, 5]

plt.figure(figsize=(16, 6))
plt.suptitle(f'x = {x}')

plt.subplot(131)
plt.hist(x, bins=[0, 1, 2, 3, 4, 5, 6])
plt.title('align="middle" (default)')

plt.subplot(132)
plt.hist(x, bins=[0, 1, 2, 3, 4, 5, 6], align='left')
plt.title('align="left"')

plt.subplot(133)
plt.hist(x, bins=[0, 1, 2, 3, 4, 5, 6], align='right')
plt.title('align="right"')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example - Overlapping histograms

# %% [markdown]
# Use the transparency value `alpha = ` to show both histograms.

# %%
x1 = [random.randint(1, 5) for _ in range(20)]
x2 = [random.randint(1, 5) for _ in range(20)]

plt.hist(x1, bins=[0, 1, 2, 3, 4, 5, 6], align='left', edgecolor='black', alpha=0.5, color='blue')
plt.hist(x2, bins=[0, 1, 2, 3, 4, 5, 6], align='left', edgecolor='black', alpha=0.5, color='blue')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example - Side-by-side histograms

# %% [markdown]
# - Assign two different sets of values to `.hist()`
#     - use a tuple (data1, data2)
# - Create a legend
# - Set a color for the edges with `edgecolor = `

# %%
# Note that _ is an index for the loop
x1 = [random.randint(1, 5) for _ in range(20)]
x2 = [random.randint(1, 5) for _ in range(20)]

plt.hist((x1, x2), bins=[1, 2, 3, 4, 5, 6], align='left', edgecolor='black', alpha=0.6, label=['$x_1$', '$x_2$'])

plt.legend()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example - Subplots with histograms

# %% [markdown]
# - Create 4 histograms
# - Each will represent the sum of two dice which are rolled N times
#     - N = 10
#     - N = 100
#     - N = 1000
#     - N = 10000
# - Generate roll values randomly
# - Add subplot titles
# - Add a figure title

# %%
plt.figure(figsize=(12, 8))
for i in range(1, 5):
    n = 10 ** i
    x1 = [random.randint(1, 6) for _ in range(n)]
    x2 = [random.randint(1, 6) for _ in range(n)]

    total = [x + y for x, y in zip(x1, x2)]

    plt.subplot(2, 2, i)
    plt.hist(total, bins=range(2, 14), align='left', color='white', edgecolor='black')
    plt.title(f'n = {n}')

plt.suptitle('Sum of 2 dice rolls')
plt.show()

# %% [markdown]
# ---
# <div class="alert alert-block alert-success">
#
#
# ### Saving a figure

# %%
# Create datasets
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [1, 4, 9, 16, 25, 36, 49, 64]


plt.plot(x, y);
plt.savefig('my-plot.png')

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Example
#
# - Create and save any figure you want

# %%
penguins = pd.read_csv('https://gist.githubusercontent.com/slopp/ce3b90b9168f2f921784de84fa445651/raw/4ecf3041f0ed4913e7c230758733948bc561f434/penguins.csv')

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
plt.scatter(penguins.flipper_length_mm, penguins.body_mass_g)
plt.title('Penguin Flipper Length VS Mass')
plt.show()

# %% [markdown]
# ### Make a scatterplot:
#
# ##### Flipper length and mass
# ##### Broken down by species
#
# - Gentoo
# - Adelie
# - Chinstrap

# %%
penguins.species
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: object

# %%
gentoo = penguins[penguins['species'] == 'Gentoo']
adelie = penguins[penguins['species'] == 'Adelie']
chinstrap = penguins[penguins['species'] == 'Chinstrap']

# %%
plt.scatter(gentoo.flipper_length_mm, gentoo.body_mass_g, alpha = 0.85)
plt.scatter(adelie.flipper_length_mm, adelie.body_mass_g, alpha = 0.7)
plt.scatter(chinstrap.flipper_length_mm, chinstrap.body_mass_g, alpha = 0.5);

# %%
# object oriented notation

# %%
flipper = penguins.flipper_length_mm
body_mass = penguins.body_mass_g

# %%
fig, ax = plt.subplots()
ax.scatter(penguins.flipper_length_mm, penguins.body_mass_g)

# %% [markdown]
# ### Pie Chart
#
# - Proportion of Data

# %%
titanic = data('titanic')

# %%
titanic.sample(5)
# Out:
#           class     age    sex survived
# 1183  3rd class  adults  women       no
# 847   3rd class  adults    man       no
# 922   3rd class  adults    man       no
# 953   3rd class  adults    man       no
# 321   1st class   child    man      yes

# %%
survivors = sum(titanic.survived == 'yes')
non_survivors = sum(titanic.survived == 'no')

# %%
# Assign labels
my_labels = ['Survived', 'Did not Survive']

# set the size of each part
sizes = [survivors, non_survivors]

# create the figure
# create the subplot (ax)

fig, ax = plt.subplots()
ax.pie(sizes, labels = my_labels, autopct = '%1.0f%%', colors = ('blue', 'firebrick'))

ax.set_title('Survival Rate for the Titanic');
